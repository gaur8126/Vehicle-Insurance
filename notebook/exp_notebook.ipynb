# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from imblearn.over_sampling import RandomOverSampler
sns.set(style="whitegrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import Datadet

# %%
df = pd.read_csv("./data.csv")
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %% [markdown]
# * 'id': Unique ID for the customer
#
# * 'Gender': Gender of the customer
#
# * 'Age': Age of the customer
#
# * 'Driving_License': [0: Customer does not have DL, 1: Customer already has DL]
#
# * 'Region_Code': Unique code for the redion of the customer
#
# * 'Previously_Insured': [1: Customer already have Vehicle Insurance, 0:Customer doesn't have Vehicle Insurance]
#
# * 'Vehicle_Age': Age of the Vehicle
#
# * 'Vehicle_Damage': [1: Customer got his/her vehicle damages in the past, 0:
# Customer don't get his/her vehicle damaged in the past]
#
# * 'Annual_Premium': The amount customer needs to pay as premium in the year
#
# * 'Policy_Sales_Channel': Anonymized Code for the channel of outreaching to
# the customer ie. Different Agents, Over Mail, Over Phone, In Person, etc.
#
# * 'Vintage': Number of Days, Customer has been associated with the company
#
# * 'Response': [1: Customer is interested, 0: Customer is not interested]

# %% [markdown]
# ## EDA

# %%
# shape of data 
df.shape
# Out:
# (381109, 12)

# %% [markdown]
# Data has 381109 raws and 12 columns

# %%
# checking the NULL values 
df.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %% [markdown]
# There is no NULL value in the data

# %%
# checking the duplicate values 
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
#  There is no duplicate value in the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %% [markdown]
# There are 3 categorical columns: Gender, Vehicle_Age and Vehicle_Damage
#
# And 9 numerical columns

# %%
df.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# 25%              0.000000    24405.000000             29.000000
# 50%              0.000000    31669.000000            133.000000
# 75%              1.000000    39400.000000            152.000000
# max              1.000000   540165.000000            163.000000
#
#              Vintage       Response
# count  381109.000000  381109.000000
# mean      154.347397       0.122563
# std        83.671304       0.327936
# min        10.000000       0.000000
# 25%        82.000000       0.000000
# 50%       154.000000       0.000000
# 75%       227.000000       0.000000
# max       299.000000       1.000000

# %%
# checking distribution for target column
df['Response'].value_counts()
# Out:
# Response
# 0    334399
# 1     46710
# Name: count, dtype: int64

# %% [markdown]
# Data is imbalance

# %%
value_counts = df['Response'].value_counts()

plt.figure(figsize=(6,4))

value_counts.plot(kind='bar')

plt.xlabel("Reaponse")
plt.ylabel("Count")
plt.title("Distribution of Responses")

plt.show()

# %%
# Checking distribution for age col 

df['Age'].hist(bins=20)
# Out:
# <Axes: >

# %%
# Scatter Plot
plt.figure(figsize=(6,4))
sns.scatterplot(x='Age', y="Annual_Premium", data=df)
plt.title("Age vs Anual_Premium")
plt.xlabel("Age")
plt.ylabel("Anual Premium")
plt.show()

# %%
## Gender-Response comparison

value_counts = df['Gender'].value_counts()
plt.figure(figsize=(4,4))

value_counts.plot(kind='bar')

plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
data = df.groupby(['Gender','Response'])['id'].count().to_frame().rename(columns={'id':'count'}).reset_index()

g = sns.catplot(x = 'Gender', y="count", col="Response", data=data, kind='bar',height=4,aspect=.7)

# %%
# driving licence by gender 

data = df.groupby(['Gender'])['Driving_License'].count().to_frame().reset_index()
sns.catplot(x='Gender',y="Driving_License", data=data, kind='bar')
data
# Out:
#    Gender  Driving_License
# 0  Female           175020
# 1    Male           206089

# %%
## Filter for only license holders (Driving License == 1)
license_holders = df[df['Driving_License'] == 1]
gender_counts = license_holders['Gender'].value_counts()

plt.figure(figsize=(4,4))
gender_counts.plot(kind='bar',color=['blue','pink'])
plt.title("Number of Male vs Female License Holders")
plt.xlabel('Gender')
plt.ylabel('Count of License Holders')
plt.xticks(rotation = 0)
plt.show()

# %%
## Customers with existing insurace 

sns.countplot(x="Previously_Insured", data=df)
plt.title("Distribution of Previously Insured")
plt.xlabel("Previously Insured")
plt.ylabel("Count")
plt.show()

# %%
# Checking vehicle age dist

sns.countplot(x='Vehicle_Age', data=df)
plt.xlabel('Vehicle Age')
plt.ylabel("Count")
plt.title("Distribution of vehicle Age")
plt.xticks(rotation = 45)
plt.show()

# %%
# Response VS Vehicle Age

data = df.groupby(['Vehicle_Age', 'Response'])['id'].count().to_frame().rename(columns={'id':'count'}).reset_index()
data
# Out:
#   Vehicle_Age  Response   count
# 0    1-2 Year         0  165510
# 1    1-2 Year         1   34806
# 2    < 1 Year         0  157584
# 3    < 1 Year         1    7202
# 4   > 2 Years         0   11305
# 5   > 2 Years         1    4702

# %%
g = sns.catplot(x='Vehicle_Age', y='count', data=data, col="Response",
                kind='bar',
                height=4, aspect=.7)

# %%
# dist for vehicle damage col 


sns.countplot(data=df, x="Vehicle_Damage")
plt.title('Distribution of Vehicle Damage')
plt.xlabel("Vehicle Damage")
plt.ylabel('count')
plt.show()

# %%
data = df.groupby(['Vehicle_Damage',"Response"])['id'].count().to_frame().rename(columns={'id':'count'}).reset_index()
g = sns.catplot(x='Vehicle_Damage', y="count",col="Response", data=data, kind='bar', height=4, aspect=0.7)
data
# Out:
#   Vehicle_Damage  Response   count
# 0             No         0  187714
# 1             No         1     982
# 2            Yes         0  146685
# 3            Yes         1   45728

# %%
df['Annual_Premium'].describe()
# Out:
# count    381109.000000
# mean      30564.389581
# std       17213.155057
# min        2630.000000
# 25%       24405.000000
# 50%       31669.000000
# 75%       39400.000000
# max      540165.000000
# Name: Annual_Premium, dtype: float64

# %%
df['Annual_Premium'].hist(bins=10)
# Out:
# <Axes: >

# %%
df[df['Annual_Premium'] > 200000]
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 1412      1413  Female   41                1         28.0                   0
# 11319    11320  Female   50                1         46.0                   1
# 13426    13427  Female   47                1         28.0                   0
# 15024    15025  Female   32                1         28.0                   0
# 25532    25533    Male   50                1         28.0                   0
# ...        ...     ...  ...              ...          ...                 ...
# 368263  368264  Female   25                1         28.0                   1
# 371910  371911  Female   23                1         37.0                   1
# 372492  372493    Male   46                1         18.0                   0
# 373415  373416    Male   56                1         28.0                   0
# 376777  376778    Male   21                1         17.0                   1
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 1412      1-2 Year            Yes        267698.0                 124.0
# 11319     1-2 Year             No        508073.0                  26.0
# 13426     1-2 Year            Yes        301762.0                 124.0
# 15024     1-2 Year            Yes        315565.0                 155.0
# 25532     1-2 Year            Yes        229935.0                 122.0
# ...            ...            ...             ...                   ...
# 368263    < 1 Year            Yes        346982.0                 124.0
# 371910    < 1 Year             No        235683.0                 152.0
# 372492    1-2 Year             No        220581.0                  26.0
# 373415    1-2 Year             No        337573.0                  26.0
# 376777    < 1 Year             No        251817.0                 160.0
#
#         Vintage  Response
# 1412         63         1
# 11319       192         0
# 13426        22         0
# 15024       150         0
# 25532        64         1
# ...         ...       ...
# 368263       74         0
# 371910      246         0
# 372492      210         0
# 373415      239         0
# 376777      292         0
#
# [112 rows x 12 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
# mapping 'Gender' col to (0,1) values

df['Gender'] = df['Gender'].map({'Female':0,'Male':1}).astype(int)

# %%
df = pd.get_dummies(df, drop_first=True).astype(int)
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1       1   44                1           28                   0
# 1   2       1   76                1            3                   0
# 2   3       1   47                1           28                   0
# 3   4       1   21                1           11                   1
# 4   5       0   29                1           41                   1
#
#    Annual_Premium  Policy_Sales_Channel  Vintage  Response  \
# 0           40454                    26      217         1
# 1           33536                    26      183         0
# 2           38294                    26       27         1
# 3           28619                   152      203         0
# 4           27496                   152       39         0
#
#    Vehicle_Age_< 1 Year  Vehicle_Age_> 2 Years  Vehicle_Damage_Yes
# 0                     0                      1                   1
# 1                     0                      0                   0
# 2                     0                      1                   1
# 3                     1                      0                   0
# 4                     1                      0                   0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     381109 non-null  int64
#  1   Gender                 381109 non-null  int64
#  2   Age                    381109 non-null  int64
#  3   Driving_License        381109 non-null  int64
#  4   Region_Code            381109 non-null  int64
#  5   Previously_Insured     381109 non-null  int64
#  6   Annual_Premium         381109 non-null  int64
#  7   Policy_Sales_Channel   381109 non-null  int64
#  8   Vintage                381109 non-null  int64
#  9   Response               381109 non-null  int64
#  10  Vehicle_Age_< 1 Year   381109 non-null  int64
#  11  Vehicle_Age_> 2 Years  381109 non-null  int64
#  12  Vehicle_Damage_Yes     381109 non-null  int64
# dtypes: int64(13)
# memory usage: 37.8 MB

# %%
X = df.drop("Response", axis=1)
y = df.Response

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((285831, 12), (95278, 12))

# %%
from sklearn.preprocessing import StandardScaler
# from sklearn.impute import SimpleImputer
# from sklearn.pipeline import Pipeline
# from sklearn.compose import ColumnTransformer
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

clf = RandomForestClassifier()

clf.fit(X_train_scaled,y_train)

y_pred = clf.predict(X_test_scaled)

print(accuracy_score(y_test, y_pred))
# Out:
# 0.8716177921450912

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

clf = RandomForestClassifier()

clf.fit(X_train,y_train)

y_pred = clf.predict(X_test)

print(accuracy_score(y_test, y_pred))
# Out:
# 0.8708726043787653

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

clf = SVC()

clf.fit(X_train_scaled,y_train)

y_pred = clf.predict(X_test_scaled)

print(accuracy_score(y_test, y_pred))
# Out:
# 0.8765192384390941

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

clf = SVC()

clf.fit(X_train,y_train)

y_pred = clf.predict(X_test)

print(accuracy_score(y_test, y_pred))
